# %% [markdown]
# # Claim check notebook
#
# This notebook is a companion validation layer. It is not theorem-bearing evidence by itself.

# %%
from sympy import Symbol, simplify
x = Symbol('x')
expr = (x + 0) - x
simplify(expr)
